# %%
import os
import shutil
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# Check version
print(tf.__version__)
# Out:
# 2.19.0

# %%
#directory
source_dir= r'OneDrive/Desktop/Git-pository/Project-I/RiceLeafDisease/archive/RiceLeafsDisease'
train_dir = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\train"
val_dir   = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\validation"
test_dir  = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\test"

# %%
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2, horizontal_flip=True)
val_test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
val_generator = val_test_datagen.flow_from_directory(val_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
test_generator = val_test_datagen.flow_from_directory(test_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
# Out:
# Found 894 images belonging to 3 classes.
# Found 225 images belonging to 3 classes.
# Found 195 images belonging to 3 classes.

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(train_generator.num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator, epochs=100, validation_data=val_generator)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.6521 - loss: 0.7801 - val_accuracy: 0.9422 - val_loss: 0.1783
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 107s 4s/step - accuracy: 0.9340 - loss: 0.1762 - val_accuracy: 0.9600 - val_loss: 0.1589
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9397 - loss: 0.1654 - val_accuracy: 0.9644 - val_loss: 0.1170
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9563 - loss: 0.1241 - val_accuracy: 0.9644 - val_loss: 0.1299
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.9624 - loss: 0.1056 - val_accuracy: 0.9556 - val_loss: 0.1206
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 108s 4s/step - accuracy: 0.9562 - loss: 0.1061 - val_accuracy: 0.9733 - val_loss: 0.0958
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 104s 4s/step - accuracy: 0.9705 - loss: 0.0858 - val_accuracy: 0.9600 - val_loss: 0.0985
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - accuracy: 0.9691 - loss: 0.0749 - val_accuracy: 0.9644 - val_loss: 0.0965
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 96s 3s/step - accuracy: 0.9832 - loss: 0.0817 - val_accuracy: 0.9689 - val_loss: 0.1120
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9706 - loss: 0.0783 - val_accuracy: 0.9689 - val_loss: 0.1032
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 148s 4s/step - accuracy: 0.9765 - loss: 0.0777 - val_accuracy: 0.9733 - val_loss: 0.0720
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.9770 - loss: 0.0772 - val_accuracy: 0.9733 - val_loss: 0.0736
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9825 - loss: 0.0527 - val_accuracy: 0.9733 - val_loss: 0.0737
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - accuracy: 0.9692 - loss: 0.0640 - val_accuracy: 0.9733 - val_loss: 0.0841
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9729 - loss: 0.0567 - val_accuracy: 0.9689 - val_loss: 0.0802
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 107s 4s/step - accuracy: 0.9753 - loss: 0.0645 - val_accuracy: 0.9689 - val_loss: 0.0912
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.9793 - loss: 0.0567 - val_accuracy: 0.9778 - val_loss: 0.0766
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.9714 - loss: 0.0615 - val_accuracy: 0.9556 - val_loss: 0.1111
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.9796 - loss: 0.0595 - val_accuracy: 0.9733 - val_loss: 0.0787
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9853 - loss: 0.0438 - val_accuracy: 0.9511 - val_loss: 0.0994
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.9785 - loss: 0.0543 - val_accuracy: 0.9644 - val_loss: 0.0837
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9749 - loss: 0.0703 - val_accuracy: 0.9778 - val_loss: 0.0797
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.9898 - loss: 0.0204 - val_accuracy: 0.9644 - val_loss: 0.1146
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9911 - loss: 0.0191 - val_accuracy: 0.9733 - val_loss: 0.0631
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.9914 - loss: 0.0197 - val_accuracy: 0.9689 - val_loss: 0.0819
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.9880 - loss: 0.0212 - val_accuracy: 0.9733 - val_loss: 0.0586
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.9945 - loss: 0.0129 - val_accuracy: 0.9733 - val_loss: 0.0708
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9778 - val_loss: 0.0595
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.9960 - loss: 0.0122 - val_accuracy: 0.9778 - val_loss: 0.0433
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9961 - loss: 0.0172 - val_accuracy: 0.9867 - val_loss: 0.0525
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step - accuracy: 0.9945 - loss: 0.0214 - val_accuracy: 0.9733 - val_loss: 0.0683

# %%
import matplotlib.pyplot as plt

epochs = range(len(history.history['loss']))

plt.figure(figsize=(10, 6))

# Plot loss
plt.plot(epochs, history.history['loss'], 'r-', label='Training Loss')
plt.plot(epochs, history.history['val_loss'], 'r--', label='Validation Loss')

# Plot accuracy
plt.plot(epochs, history.history['accuracy'], 'b-', label='Training Accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'b--', label='Validation Accuracy')

plt.title('Training & Validation Accuracy and Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print("Test Accuracy:", test_accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9718 - loss: 0.1258
# Test Accuracy: 0.9692307710647583

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

test_image_path = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\test\bacterial_leaf_blight\bacterial_leaf_blight (3).JPG"
img = image.load_img(test_image_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

plt.imshow(img)
plt.axis("off")
plt.title("Input Image")
plt.show()

prediction = model.predict(img_array)
predicted_class = train_generator.class_indices
predicted_label = list(predicted_class.keys())[np.argmax(prediction)]
print("Predicted Class:", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Class: bacterial_leaf_blight

# %%
import random
import matplotlib.pyplot as plt

class_names = ['bacterial_leaf_blight', 'brown_spot', 'healthy']

# Get the first batch from the generator
images, labels = test_generator[0]

# Choose a random image from the batch
idx = random.randint(0, len(images) - 1)
img = images[idx]
label = labels[idx]

prediction = model.predict(np.expand_dims(img, axis=0))
predicted_index = np.argmax(prediction)
true_index = np.argmax(label)

# Display the image
plt.imshow(img)
plt.axis("off")
plt.title(f"Label: {label}")
plt.title(f"Predicted: {class_names[predicted_index]}\nActual: {class_names[true_index]}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img_path = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\test\bacterial_leaf_blight\bacterial_leaf_blight (306).JPG"
img = image.load_img(img_path, target_size=(224, 224))  # Adjust if your model uses different size

# Display the image
plt.imshow(img)
plt.axis("off")
plt.title("Input Image")
plt.show()

# Preprocess the image manually
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # ✅ Rescale just like ImageDataGenerator(rescale=1./255)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict
prediction = model.predict(img_array)

# Class decoding
class_names = ['bacterial_leaf_blight', 'brown_spot', 'healthy']  # Adjust based on your project
predicted_class = class_names[np.argmax(prediction)]

print(f"✅ Predicted Class: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# ✅ Predicted Class: bacterial_leaf_blight

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img_path = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\test\healthy\healthy (261).jpg"
img = image.load_img(img_path, target_size=(224, 224))  # Adjust if your model uses different size

# Display the image
plt.imshow(img)
plt.axis("off")
plt.title("Input Image")
plt.show()

# Preprocess the image manually
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # ✅ Rescale just like ImageDataGenerator(rescale=1./255)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict
prediction = model.predict(img_array)

# Class decoding
class_names = ['bacterial_leaf_blight', 'brown_spot', 'healthy']  # Adjust based on your project
predicted_class = class_names[np.argmax(prediction)]

print(f"✅ Predicted Class: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# ✅ Predicted Class: healthy

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img_path = r"C:\Users\neha_\OneDrive\Desktop\Git-pository\Project-I\RiceLeafDisease\archive\RiceLeafsDisease\test\brown_spot\brown_spot (166).jpg"
img = image.load_img(img_path, target_size=(224, 224))  # Adjust if your model uses different size

# Display the image
plt.imshow(img)
plt.axis("off")
plt.title("Input Image")
plt.show()

# Preprocess the image manually
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # ✅ Rescale just like ImageDataGenerator(rescale=1./255)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict
prediction = model.predict(img_array)

# Class decoding
class_names = ['bacterial_leaf_blight', 'brown_spot', 'healthy']  # Adjust based on your project
predicted_class = class_names[np.argmax(prediction)]

print(f"✅ Predicted Class: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ✅ Predicted Class: brown_spot

# %%
model.save("plant_disease_classifier.keras")

# %%
from tensorflow.keras.models import load_model

model = load_model("plant_disease_classifier.keras")

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Get true labels and predictions
y_true = []
y_pred = []

# Loop over test data generator
for i in range(len(test_generator)):
    images, labels = test_generator[i]  # one batch
    preds = model.predict(images)
    
    y_true.extend(np.argmax(labels, axis=1))          # true class index
    y_pred.extend(np.argmax(preds, axis=1))           # predicted class index

# Step 2: Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Step 3: Compute metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted')
rec = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("✅ Evaluation Metrics:")
print(f"Accuracy       : {acc:.4f}")
print(f"Precision      : {prec:.4f}")
print(f"Recall         : {rec:.4f}")
print(f"F1 Score       : {f1:.4f}")

# Step 4: Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
class_names = ['Brown Spot', 'Bacterial Leaf Blight', 'Healthy']  # adjust as per your dataset

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Optional: Full classification report
print("\n📊 Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# ✅ Evaluation Metrics:
# Accuracy       : 0.9692
# Precision      : 0.9718
# Recall         : 0.9692
# F1 Score       : 0.9692
# 📊 Classification Report:
#
#                        precision    recall  f1-score   support
#
#            Brown Spot       1.00      1.00      1.00        65
# Bacterial Leaf Blight       0.92      1.00      0.96        65
#               Healthy       1.00      0.91      0.95        65
#
#              accuracy                           0.97       195
#             macro avg       0.97      0.97      0.97       195
#          weighted avg       0.97      0.97      0.97       195

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Reuse y_true and y_pred from earlier
cm = confusion_matrix(y_true, y_pred)
class_names = ['Brown Spot', 'Bacterial Leaf Blight', 'Healthy']

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

# Save to file
plt.savefig("confusion_matrix.png")
plt.close()
print("✅ Confusion matrix saved as 'confusion_matrix.png'")
# Out:
# ✅ Confusion matrix saved as 'confusion_matrix.png'
